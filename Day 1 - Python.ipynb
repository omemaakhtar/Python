# %%
print ("My name is Omema Akhtar")
print ("I work at BML as a VP")
print ("I live in Karachi")
# Out:
# My name is Omema Akhtar
# I work at BML as a VP
# I live in Karachi

# %%
print ("This is my first step")
print("Print under brackets is a function and whatever we save inside is called a string")
# Out:
# This is my first step
# Print under brackets is a function and whatever we save inside is called a string

# %%
name = "Omema"
profession = "Banking"
years_of_experience = 16

print (name)
print (profession)
print (years_of_experience)
# Out:
# Omema
# Banking
# 16

# %%
name = "Zahida"
age = 35
profession = "Banking and wasting time"
reason = "She is my friend and very dear to me"

print (name)
print (age)
print (reason)
# Out:
# Zahida
# 35
# She is my friend and very dear to me

# %%
personal_information = "My name is Omema Akhtar and currently doing CFA. I am a banker by profession"
Aim = "I love learning new things and Now i am trying my luck with programing. It is quite fascinitating to code"
Hobbies = "I love reading traveling and gyming"
Expand = "I have travelled to multiple countries include UAE, SAR, Malaysia and now planning to go to Indonesia"
Closing = "I am really looking forward to the upcoming year as I have my plan to be an expert in programming and LLM. I just hope i remain consistent"

print (personal_information)
print (Aim)
print (Hobbies)
print (Expand)
print (Closing)
# Out:
# My name is Omema Akhtar and currently doing CFA. I am a banker by profession
# I love learning new things and Now i am trying my luck with programing. It is quite fascinitating to code
# I love reading traveling and gyming
# I have travelled to multiple countries include UAE, SAR, Malaysia and now planning to go to Indonesia
# I am really looking forward to the upcoming year as I have my plan to be an expert in programming and LLM. I just hope i remain consistent
